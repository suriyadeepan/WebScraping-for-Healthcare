# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ..
# Out:
# /home/suriya/dcu/PeerLearning

# %%
search_template = "https://www.hpra.ie/homepage/medicines/medicines-information/find-a-medicine/results?page={}&field=&query="
url = search_template.format(1)

# %%
from phscrape import hpra

df = hpra.crawl_k(30)
df
# Out:
# Aciclovir 200mg/5ml Oral Suspension:   1%|          | 3/509 [00:08<24:13,  2.87s/it]
#                                                  Name  ...                                                PIL
# 0   0.18 % w/v Sodium Chloride and 4 % w/v Glucose...  ...  https://www.hpra.ie/img/uploaded/swedocuments/...
# 1   0.18%w/v Sodium Chloride and 4.0% w/v Glucose ...  ...  https://www.hpra.ie/img/uploaded/swedocuments/...
# 2              0.9 % w/v Sodium Chloride Injection BP  ...  https://www.hpra.ie/img/uploaded/swedocuments/...
# 3   0.9% Sodium Chloride Intravenous Infusion Solu...  ...  https://www.hpra.ie/img/uploaded/swedocuments/...
# 4         1% w/v Lidocaine Hydrochloride Injection BP  ...  https://www.hpra.ie/img/uploaded/swedocuments/...
# 5         2% w/v Lidocaine Hydrochloride Injection BP  ...  https://www.hpra.ie/img/uploaded/swedocuments/...
# 6            5% Glucose Intravenous Infusion Solution  ...  https://www.hpra.ie/img/uploaded/swedocuments/...
# ...

# %%
df.loc[0]["SPC"]
# Out:
# 'https://www.hpra.ie/img/uploaded/swedocuments/Licence_PA0179-003-006_10092019132631.pdf'
